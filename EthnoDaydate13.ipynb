# %%
#Task 1: Even or Odd using Control Statement

num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Enter a number:  2
# Even Number

# %%
#Task 2: Number Guessing Game using Random

import random

number = random.randint(1, 10)

guess = int(input("Guess a number between 1 and 10: "))

if guess == number:
    print("Correct! You guessed it right.")
else:
    print("Wrong guess. The number was:", number)
# Out:
# Guess a number between 1 and 10:  4
# Wrong guess. The number was: 10
