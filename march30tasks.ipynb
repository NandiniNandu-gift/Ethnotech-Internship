# %%
#Task 1:Resume HTML task

from IPython.display import HTML
HTML("""
<!DOCTYPE html>
<html>
<head>
    <style>
        .name { text-align: center; }
        .contact { text-align: right; }
        .heading { text-align: left; }
        .content { text-align: justify; }
    </style>
</head>
<body>

<h1 class="name">Nandini K V</h1>

<p class="contact">
Email: nandini@gmail.com <br>
Phone: 1234567890
</p>

<hr style="width: 60%; margin: auto;">

<h2 class="heading">Education</h2>
<p class="content">
I am pursuing engineering in Computer Science with knowledge in programming and web development.
</p>

<h2 class="heading">Skills</h2>
<p class="content">
HTML, CSS, JavaScript, Python, SQL
</p>

</body>
</html>
""")
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <style>
#         .name { text-align: center; }
#         .contact { text-align: right; }
#         .heading { text-align: left; }
#         .content { text-align: justify; }
#     </style>
# </head>
# <body>
#
# <h1 class="name">Nandini K V</h1>
#
# <p class="contact">
# Email: nandini@gmail.com <br>
# Phone: 1234567890
# </p>
#
# <hr style="width: 60%; margin: auto;">
#
# <h2 class="heading">Education</h2>
# <p class="content">
# I am pursuing engineering in Computer Science with knowledge in programming and web development.
# </p>
#
# <h2 class="heading">Skills</h2>
# <p class="content">
# HTML, CSS, JavaScript, Python, SQL
# </p>
#
# </body>
# </html>

# %%
#Task 2:News Articlefrom IPython.display import HTML

from IPython.display import HTML
HTML("""
<!DOCTYPE html>
<html>
<body>

<h1 style="text-align: center;">Technology News</h1>

<p style="text-align: right;">By Nandini</p>

<hr>

<p style="text-align: justify;">
Technology is improving day by day and changing human life in many ways.
</p>

<p style="text-align: center; font-style: italic;">
"Technology connects the world"
</p>

<footer style="text-align: left;">
© News Page
</footer>

</body>
</html>
""")
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h1 style="text-align: center;">Technology News</h1>
#
# <p style="text-align: right;">By Nandini</p>
#
# <hr>
#
# <p style="text-align: justify;">
# Technology is improving day by day and changing human life in many ways.
# </p>
#
# <p style="text-align: center; font-style: italic;">
# "Technology connects the world"
# </p>
#
# <footer style="text-align: left;">
# © News Page
# </footer>
#
# </body>
# </html>

# %%
#Task 3:Product Advertisement

from IPython.display import HTML
HTML("""
<!DOCTYPE html>
<html>
<body>

<h1 style="text-align: center;">Smart Watch</h1>

<p style="text-align: right;">Price: ₹1999</p>

<hr>

<p style="text-align: justify;">
This smartwatch helps track your health and fitness. It is stylish and easy to use.
</p>

<div style="text-align: center;">
<button>Buy Now</button>
</div>

</body>
</html>
""")
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h1 style="text-align: center;">Smart Watch</h1>
#
# <p style="text-align: right;">Price: ₹1999</p>
#
# <hr>
#
# <p style="text-align: justify;">
# This smartwatch helps track your health and fitness. It is stylish and easy to use.
# </p>
#
# <div style="text-align: center;">
# <button>Buy Now</button>
# </div>
#
# </body>
# </html>

# %%
#Task 4:School Notice board

from IPython.display import HTML
HTML("""
<!DOCTYPE html>
<html>
<body>

<h1 style="text-align: center;">ABC School</h1>

<p style="text-align: right;">Date: 30 March 2026</p>

<hr>

<p style="text-align: justify;">
Annual exams will start next week. Students must prepare well.
</p>

<p style="text-align: center; color: red; font-weight: bold;">
Important: Bring hall ticket
</p>

<footer style="text-align: left;">
Principal Office
</footer>

</body>
</html>
""")
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h1 style="text-align: center;">ABC School</h1>
#
# <p style="text-align: right;">Date: 30 March 2026</p>
#
# <hr>
#
# <p style="text-align: justify;">
# Annual exams will start next week. Students must prepare well.
# </p>
#
# <p style="text-align: center; color: red; font-weight: bold;">
# Important: Bring hall ticket
# </p>
#
# <footer style="text-align: left;">
# Principal Office
# </footer>
#
# </body>
# </html>
